# %%
content = """Lorem Ipsum is simply dummy text of the printing and typesetting industry. 
Lorem Ipsum has been the industry standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. 
It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. 
It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."""

question 1: a) count the number of char
            b) count of lines
            c) count the number of words

# %%
f = open('data.txt','r')
no_of_char = len(f.read())
f.seek(0)
no_of_words = len(f.read().split())

# %%
no_of_char, no_of_words
# Out:
# (576, 91)

# %%
f.read()
# Out:
# ''

# %% [markdown]
# # methods to do on operation on Read mode
#
# - read() - reads the whole content of the file and returns a string object
# - read(char) - reads the specified no of characters from current position and returns string
# - readline() - reads the current line from the current position of the cursor and retruns a string object
# - readlines() - reads the whole content of the file and retuns a list of string where every element is a string and represents a line

# %%
f = open('data.txt','r')
f.read()
# Out:
# 'Lorem Ipsum is simply dummy text of the printing and typesetting industry. \nLorem Ipsum has been the industry standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. \nIt has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. \nIt was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.\n'

# %%
f = open('data.txt','r')
f.read(10)
# Out:
# 'Lorem Ipsu'

# %%
f = open('data.txt','r')
f.seek(79)
f.readline()
# Out:
# 'em Ipsum has been the industry standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. \n'

# %%
f = open('data.txt','r')
f.readlines()
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry. \n',
#  'Lorem Ipsum has been the industry standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. \n',
#  'It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. \n',
#  'It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.\n']

# %%
10,20
# Out:
# (10, 20)

# %%
# methods to do on write mode operation

- write('str')
- writelines(['str1\n','str2\n','str3\n'])

# %%
f = open('write_method.py','w')
f.write('str')
f.close()

# %%
f = open('write_method.py','w')
f.writelines(['str1\n','str2\n','str3\n'])
f.close()

# %%
content = """Lorem Ipsum is simply dummy text of the printing and typesetting industry. 
Lorem Ipsum has been the industry standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. 
It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. 
It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."""

question 1: a) count the number of char
            b) count of lines
            c) count the number of words

# %%
f = open('data.txt','r')
no_of_char = len(f.read())
f.seek(0)
no_of_words = len(f.read().split())
f.seek(0)
no_of_lines = len(f.readlines())

# %%
no_of_lines
# Out:
# 4

# %%
file handling with 'with' statment

# %%
f = open('data.txt','w')
no_of_char = len(f.read())
f.seek(0)
no_of_words = len(f.read().split())
f.seek(0)
no_of_lines = len(f.readlines())

# %%
with open('data.txt','r') as f:
    no_of_char = len(f.read())
    f.seek(0)
    no_of_words = len(f.read().split())
    f.seek(0)
    no_of_lines = len(f.readlines())

# %%
f = open('test.txt','w')
f.write('abc')
f.write('xyz')
f.close()

# %%
with open('test.txt','w') as f:
    f.write('afsan')
    f.write('khan')

# %%
# take a image image1.png. copy the content of the image in a new file image2.jpg

# %%
f = open('image1.jpeg','rb')
data = f.read()

f = open('image2.jpeg','wb')
f.write(data)
f.close()

# %%
# Exceptional_handling

# %%
# types of error

1. compile time error - syntax error, indentation error
2. logical error - error done by user in logic
3. run time error - divide by zero, type error , name error etc

Note : Exceptional handling is sued to handle only runtime errors

# %%
.py ---> compile(synatx and indentation) ----> interprert

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %%
num1 = int(input('enter the number 1'))
num2 = int(input('enter the number 2'))

print(num1/num2)
# Out:
# enter the number 1100
# enter the number 20
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [38], in <cell line: 4>()
#       1 num1 = int(input('enter the number 1'))
#       2 num2 = int(input('enter the number 2'))
# ----> 4 print(num1/num2)
#
# ZeroDivisionError: division by zero

# %%
keywords that we will be using in exceptional handling

try
except
else
finally
raise

# %%
try and except

try : only the code whihc will be going to raise an error will be wriiten here
except : alternalte code that will be execute when try rasies an error

# %%
try:
    # some code
except:
    # alternate code

# %%
num1 = int(input('enter the number 1'))
num2 = int(input('enter the number 2'))

print(num1/num2)
print('end of the code')
# Out:
# enter the number 1100
# enter the number 20
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [40], in <cell line: 4>()
#       1 num1 = int(input('enter the number 1'))
#       2 num2 = int(input('enter the number 2'))
# ----> 4 print(num1/num2)
#       5 print('end of the code')
#
# ZeroDivisionError: division by zero

# %%
num1 = int(input('enter the number 1'))
num2 = int(input('enter the number 2'))
try:
    print(num1/num2)
except:
    print('division by zero is not applicable')
    
print('end of the code')
# Out:
# enter the number 110
# enter the number 20
# division by zero is not applicable
# end of the code

# %%
try , except , else

- execution will go to the except block when there is an error in try
- execution will go to the else block when there is no error in try

# %%
try:
    # some code
except:
    # exec of  error in try block
else:
    # exec of no error in try block

# %%
num1 = int(input('enter the number 1'))
num2 = int(input('enter the number 2'))
try:
    c = num1/num2
except:
    print('division by zero is not applicable')

print(c)
print('end of the code')
# Out:
# enter the number 1100
# enter the number 20
# division by zero is not applicable
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 8>()
#       5 except:
#       6     print('division by zero is not applicable')
# ----> 8 print(c)
#       9 print('end of the code')
#
# NameError: name 'c' is not defined

# %%
num1 = int(input('enter the number 1'))
num2 = int(input('enter the number 2'))
try:
    c = num1/num2
    print(c)
except:
    print('division by zero is not applicable')

print('end of the code')
# Out:
# enter the number 1100
# enter the number 210
# 10.0
# end of the code

# %%
num1 = int(input('enter the number 1'))
num2 = int(input('enter the number 2'))
try:
    c = num1/num2 
except:
    print('division by zero is not applicable')
else:
    print(c)

print('end of the code')
# Out:
# enter the number 1100
# enter the number 20
# division by zero is not applicable
# end of the code
