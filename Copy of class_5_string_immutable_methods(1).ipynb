# %%
  a = 'python'

print(id(a))
# Out:
# 140342221087088

# %%
# immutable - you cannot chnage the object when an datatype is immutable

# %%
a[0] = 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tz/1bkg3flj25ld_mcgv99ct6w80000gn/T/ipykernel_11376/1387481972.py in <module>
# ----> 1 a[0] = 's'
#
# TypeError: 'str' object does not support item assignment

# %%
x = 'python'
print(id(x))
x = 'cython'
print(id(x))
print(x)
# Out:
# 140342221087088
# 140341949555888
# cython

# %%
# Methods - pre defined funnction to make our task easier

# %%
# to find the methods in the str data type

print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
s = 'this is the python class'
s1 = 'this is THE python class'

# capitalize - it capitalises the first letter of the sentence and lower case all the other char
print(s.capitalize())
print(s1.capitalize())

#upper - converts to upper case
print(s.upper())
print(s1.upper())

#lower - converts to lower case
print(s.lower())
print(s1.lower())

# Swapcase - it converts uppercase to lopwerase and lowercase to uppercase
print(s.swapcase())
print(s1.swapcase())

#title - converts each words first letter to uppercase
print(s.title())
print(s1.title())
# Out:
# This is the python class
# This is the python class
# THIS IS THE PYTHON CLASS
# THIS IS THE PYTHON CLASS
# this is the python class
# this is the python class
# THIS IS THE PYTHON CLASS
# THIS IS the PYTHON CLASS
# This Is The Python Class
# This Is The Python Class

# %%
# functions that return a bool value

# 1. startwith --> Return True if string starts with the specified prefix else False

s = 'hello world'
print(s.startswith('ello'))

print(s.startswith('o ',4,10))

# 2. ends with - return True if string ends with a specified suffix else false
s = 'hello world'
print(s.endswith('rld'))

print(s.endswith('rl',4,10))
# Out:
# False
# True
# True
# True

# %%
s1 = 'abc'
s2 = '123abc'
s3 = '*'
s4 = '112'

#3. isalnum - check if a given string is either a num or alphabet or mix of both(alnum)
print(s1.isalnum()) # true
print(s2.isalnum()) # true
print(s3.isalnum()) # false
print(s4.isalnum()) # True

print('-'*20)
#4. isaplha - check if each char is an alphabet or not
print(s1.isalpha()) # True
print(s2.isalpha()) # False
print(s3.isalpha()) # false
print(s4.isalpha()) # False

print('-'*20)
#5. isnumeric - check if each char is an num or not
print(s1.isnumeric()) 
print(s2.isnumeric()) 
print(s3.isnumeric()) 
print(s4.isnumeric()) 

print('-'*20)
s1 = 'abc'
s2 = '123abc'
s3 = '*'
s4 = '112'
#6. isidentifier - check if string is a valid identifier or not
print(s1.isidentifier()) 
print(s2.isidentifier()) 
print(s3.isidentifier()) 
print(s4.isidentifier()) 

print('-'*20)
#6. isascii - check if all the char are an ascii table or not
print(s1.isascii()) 
print(s2.isascii()) 
print(s3.isascii()) 
print(s4.isascii())
print('flō'.isascii())
# Out:
# True
# True
# False
# True
# --------------------
# True
# False
# False
# False
# --------------------
# False
# False
# False
# True
# --------------------
# True
# False
# False
# False
# --------------------
# True
# True
# True
# True
# False

# %% [markdown]
# # Escape char

# %%
# \n - new line

print('afsan\nkhan')
# Out:
# afsan
# khan

# %%
# \ - back slash

print('afsan did\'nt like the movie')
# Out:
# afsan did'nt like the movie

# %%
print('afsan\\nkhan')
# Out:
# afsan\nkhan

# %%
# \b - backspace

print('afsan\bkhan')
# Out:
# khan

# %%
print('ab'+'\b'+'c')
# Out:
# c

# %%
# \r - carrige return

text = 'hello\rworlds'
print(text)
# Out:
# worlds

# %%
#\t - 2 spaces 
print('afsan\tkhan')
print('afsan    khan')
# Out:
# afsan	khan
# afsan    khan

# %%
# r - rawstring

print('afsan\\tkhan')
# Out:
# afsan\tkhan

# %%
print(r'afsan\tkhan')
# Out:
# afsan\tkhan

# %%
s1 = 'abc'
s2 = 'ABC'
s3 = '*av'
s4 = '112'

# isupper
print(s1.isupper())
print(s2.isupper())
print(s3.isupper())
print(s4.isupper())

print('-'*20)
# islower
print(s1.islower())
print(s2.islower())
print(s3.islower())
print(s4.islower())

print('-'*20)
# istitle
print(s1.istitle())
print(s2.istitle())
print(s3.istitle())
print(s4.istitle())
# Out:
# False
# True
# False
# False
# --------------------
# True
# False
# True
# False
# --------------------
# False
# False
# False
# False

# %%
# strip, rstrip , lstrip

# strip - removes the specified char from both the ends
a = '   pyhton  '
print(a)
print(a.strip()) #deafult is space

a = '***pyhton*****'
print(a)
print(a.strip('*')) #deafult is space
# Out:
#    pyhton
# pyhton
# ***pyhton*****
# pyhton

# %%
# rstrip - removes the specified char from the right side
a = '***pyhton*****'
print(a)
print(a.rstrip('*')) #deafult is space
# Out:
# ***pyhton*****
# ***pyhton

# %%
# lstrip - removes the specified char from the left side
a = '***pyhton*****'
print(a)
print(a.lstrip('*')) #deafult is space
# Out:
# ***pyhton*****
# pyhton*****

# %%
username = input('please enter the username')
password = input('please enter the password')

if username.strip() == 'Afsan' and password.strip() == 'devil':
    print('login success')
    
else:
    print('invalid cred')
# Out:
# please enter the usernameAfsan
# please enter the passworddevil
# login success

# %%
# find, rfind, index and rindex

# - this method finds the starting index of the specified char/words

data = 'today we have chelsea vs liverpool final'
print(data.find('chelsea'))
# Out:
# 14

# %%
data = 'today we have chelsea vs liverpool final'
print(data.find('v'))
# Out:
# 11

# %%
data = 'today we have chelsea vs liverpool final'
print(data.rfind('chelsea'))
# Out:
# 14

# %%
data = 'hey were are you'
print(data.rfind('e'))
# Out:
# 11

# %%
data = 'hey were are you'
print(data.find('e'))
# Out:
# 1

# %%
data = 'today we have chelsea vs liverpool final'
print(data.rindex('chelsea'))
# Out:
# 14

# %%
data = 'hey were are you'
print(data.index('e'))

data = 'hey were are you'
print(data.find('e'))
# Out:
# 1
# 1

# %%
data = 'hey were are you'
print(data.rindex('e'))

data = 'hey were are you'
print(data.rfind('e'))
# Out:
# 11
# 11

# %%
data = 'hey were are you'
print(data.rindex('v'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tz/1bkg3flj25ld_mcgv99ct6w80000gn/T/ipykernel_11376/1306925486.py in <module>
#       1 data = 'hey were are you'
# ----> 2 print(data.rindex('v'))
#
# ValueError: substring not found

# %%
data = 'hey were are you'
print(data.rfind('v'))
# Out:
# -1

# %%
# note - the only diff between find and index is that if the char is not presnet in the string find will give -1 
and index will raise an error

# %%
# ljust(left adjustment) rjust(r adjustement)

text = 'afsan'
print('hello' , text , 'khan')
print('hello' , text.ljust(20), 'khan')
# Out:
# hello afsan khan
# hello afsan                khan

# %%
text = ''
print('hello' , text , 'khan')
print('hello' , text.rjust(20), 'khan')
# Out:
# hello afsan khan
# hello                afsan khan

# %%
# replace - replaces the char

data = 'the only diff between find and index is that'
print(data.replace('find', 'found'))
# Out:
# the only diff between found and index is that

# %%
data = 'the only diff between find and index is that'
print(data.replace(' ', '*'))
# Out:
# the*only*diff*between*find*and*index*is*that

# %%
# split - it will convert the string into list data type

data.split() # deafult value is space
# Out:
# ['the', 'only', 'diff', 'between', 'find', 'and', 'index', 'is', 'that']

# %%
# split - it will convert the string into list data type
data = 'the only diff between find and index is that'
data.split('o') # deafult value is space
# Out:
# ['the ', 'nly diff between find and index is that']

# %%
data
# Out:
# 'the only diff between find and index is that'

# %%
data = 'the only diff between find and index is that'
data.split('i') # deafult value is space
# Out:
# ['the only d', 'ff between f', 'nd and ', 'ndex ', 's that']

# %%
# join - list to str

a = ['the', 'only', 'diff', 'between', 'find', 'and', 'index', 'is', 'that']
print('\n'.join(a))
# Out:
# the
# only
# diff
# between
# find
# and
# index
# is
# that

# %%
sunday = list
properties
methods
shallow and deep copy
for loop
list comphrension
# Out:
# 'i love play fotball'

# %%
a = "Python"

i = 0 
while i < len(a)
 print(a[i]*(i+1))
 i=i+1
