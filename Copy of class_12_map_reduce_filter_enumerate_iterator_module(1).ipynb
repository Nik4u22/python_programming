# %%
map()

the map fucntion takes two args

1. a function
2. a seq iterable

map(func , iterable)

# %%
temp_c = [0, 22.5, 40, 60]
temp_f = []

(9/5)*T + 32

# %%
temp_c = [0,22.5, 40,60]
temp_f = []
for i in temp_c:
    temp_f.append((9/5)*i +32)
print(temp_f)
# Out:
# [32.0, 72.5, 104.0, 140.0]

# %%
def fah(T):
    return (9/5)*T +32

# %%
list(map(fah, temp_c))
# Out:
# [32.0, 72.5, 104.0, 140.0]

# %%
list(map(lambda T: (9/5)*T +32 , temp_c))
# Out:
# [32.0, 72.5, 104.0, 140.0]

# %%
a = [1,2,3,4,5]
b = [5,6,7,8,9]

c = [6,8,10,12,14]

list(map(lambda x,y=5: x+y , a,b))
# Out:
# [6, 8, 10, 12, 14]

# %%
reduce

"""
1. a function
2. a seq iterable
"""
# note - it always takes 2 args as a fucntion
sum, prod , min, max, avg

# %%
b = [5,6,7,8,9]
from functools import reduce
reduce(lambda x,y:x+y, b)
# Out:
# 35

# %%
reduce(lambda x,y:x if x > y else y, b)
# Out:
# 9

# %%
# Out:
# 5

# %%
reduce(lambda x,y:(x+y)/2, b)
# Out:
# 8.0625

# %%
b = ['Afsan','messi','ronaldo']
from functools import reduce
reduce(lambda x,y:x if len(x) > len(y) else y, b)
# Out:
# 'ronaldo'

# %%
# filter
"""
1. a function
2. a seq iterable
"""

the fucntion need to return bool value. this function will be applied to every element of the iterable, only
the function return True that element will be added in the final output

# %%
a = [5,3,7,8,2,4,8,9]
list(filter(even,a))
# Out:
# [8, 2, 4, 8]

# %%
a = [5,3,7,8,2,4,8,9]
list(filter(lambda num : num%2==0,a))
# Out:
# [8, 2, 4, 8]

# %%
map  - apply same logiv on all element
reduce - sum , agg , min , max
filter - filter the element based on the logic

# %%
lst = ['akzelxw@hotmail.com',
'elum@gmail.com',
'akbar.caakaterasu@gmail.com',
'akarui.kibuno@gmail.com',
'ajsparkchick@hotmail.com',
'ajmeia@yahoo.com',
'ajhnstn87@gmail.com',
'ailuvzhoko4@hotmail.com',
'ailuvzhoko3@hotmail.com',
'ailuvzhoko2@hotmail.com',
'ailuvzhoko@hotmail.com',
'aillensiquioco@aol.com',
'ahmovic_ines@hotmail.com',
'ahmed_g300@yahoo.com',
'ahmadjazlan@gmail.com',
'ahmad_ridho19@yahoo.com']

# 1. extract all the username from the list
# 2. extract only those elements which has domain gmail.com

# %%
# 1. extract all the username from the list

list(map(lambda emails : emails.split('@')[0] , lst ))
# Out:
# ['akzelxw',
#  'elum',
#  'akbar.caakaterasu',
#  'akarui.kibuno',
#  'ajsparkchick',
#  'ajmeia',
#  'ajhnstn87',
#  'ailuvzhoko4',
#  'ailuvzhoko3',
#  'ailuvzhoko2',
#  'ailuvzhoko',
#  'aillensiquioco',
#  'ahmovic_ines',
#  'ahmed_g300',
#  'ahmadjazlan',
#  'ahmad_ridho19']

# %%
list(filter(lambda emails :emails.split('@')[1] == 'gmail.com' else  , lst ))q
# Out:
#   Input In [28]
#     list(filter(lambda emails :emails.split('@')[0] if emails.split('@')[1] == 'gmail.com' , lst ))
#                                                                                            ^
# SyntaxError: invalid syntax

# %%
# enumerate

it is used with the loop

enumerate()

# %%
list(enumerate([10,20,30,40,50]))
# Out:
# [(0, 10), (1, 20), (2, 30), (3, 40), (4, 50)]

# %%
list(enumerate([10,20,30,40,50],10))
# Out:
# [(10, 10), (11, 20), (12, 30), (13, 40), (14, 50)]

# %%
a = [1,4,5,3,2,5,6,7,8,3,9,1,2,3]

# find all the index of the element 3

for i in enumerate(a):
    if i[1]==3:
        print(i[0])
# Out:
# 3
# 9
# 13

# %%
for index,ele in enumerate(a):
    if ele==3:
        print(index)
# Out:
# 3
# 9
# 13

# %%
for index,ele in enumerate(a):
    if i[1]==3:
        print(i[0])

# %%
i,j = (0,10)

# %%
# iterable

a = [1,2,3,4,5]

# %%
len(a)
# Out:
# 5

# %%
from iterable objects only we can create a iterator

in loop

# %%
lst = [10,20,30,40,50]

my_iter = iter(lst)

# %%
next(my_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 next(my_iter)
#
# StopIteration:

# %%
# Module

- a python file with extension .py is called as module

types of module

- builin - reduce , map, os
- user defined - any function defined by the user which we can import it

# %%
# global name space

print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'quit']

# %%
a = 10

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_ih', '_ii', '_iii', '_oh', 'a', 'exit', 'get_ipython', 'quit']

# %%
print(a)
# Out:
# 10

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
def sum():
    return 10+20

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_ih', '_ii', '_iii', '_oh', 'a', 'exit', 'get_ipython', 'quit', 'sum']

# %%
# different ways of importing the module

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'quit']

# %%
import math

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'math', 'quit']

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.pi
# Out:
# 3.141592653589793

# %%
# 2nd way
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'quit']

# %%
from math import *

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_ih', '_ii', '_iii', '_oh', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exit', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'get_ipython', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'quit', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
pi
# Out:
# 3.141592653589793

# %%
# 3 way
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'quit']

# %%
from math import pi,sqrt

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '_4', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_i5', '_i6', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'pi', 'quit', 'sqrt']

# %%
pi
# Out:
# 3.141592653589793

# %%
# 4 way - aliasing
print(dir())
import math as mt
print(dir())
# Out:
# ['In', 'Out', '_', '_4', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'pi', 'quit', 'sqrt']
# ['In', 'Out', '_', '_4', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'mt', 'pi', 'quit', 'sqrt']

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '_1', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'quit']

# %%
import my_module

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '_1', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'my_module', 'quit']

# %%
dir(my_module)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'even_or_odd',
#  'palindrome']

# %%
my_module.even_or_odd(10)
# Out:
# even

# %%
my_module.palindrome('abc')
# Out:
# not a palindrome

# %%
print(dir(__builtin__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %%
import sys

sys.path
# Out:
# ['/Users/afsankhan/personal_project/Tutort/april_batch_python',
#  '/Users/afsankhan/opt/anaconda3/lib/python39.zip',
#  '/Users/afsankhan/opt/anaconda3/lib/python3.9',
#  '/Users/afsankhan/opt/anaconda3/lib/python3.9/lib-dynload',
#  '',
#  '/Users/afsankhan/opt/anaconda3/lib/python3.9/site-packages',
#  '/Users/afsankhan/opt/anaconda3/lib/python3.9/site-packages/aeosa']

# %%
import my_module
# Out:
# afsan
# khan

# %%
# advanges of using module

1. code resua
2. readbale
3. easy to debug
4. it makes code more modular

# %%
import math

# %%
math.
# Out:
# 3.141592653589793

# %%
from math import pi
math.pi.real
# Out:
# 3.141592653589793
